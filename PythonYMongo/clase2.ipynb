# %% [markdown]
# https://jarroba.com/python-mongodb-driver-pymongo-con-ejemplos/

# %%
#pip install pymongo

# %%
from pymongo import MongoClient

# %%
class Futbolista:

    def __init__(self, nombre: str, apellidos: str, edad: int, internacional: bool):
        self.nombre = nombre
        self.apellidos = apellidos
        self.edad = edad
        self.internacional = internacional

    def toDBCollection(self):
        return {
            "nombre": self.nombre,
            "apellidos": self.apellidos,
            "edad": self.edad,
            "internacional": self.internacional
        }

    def __str__(self):
        return f"Nombre: {self.nombre} - Apellidos: {self.apellidos} - Edad: {self.edad} - Internacional: {self.internacional}"

# %%
# Creo una lista de objetos futbolista a insertar en la BD
futbolistas = [
    Futbolista('Iker','Casillas',33, True),
    Futbolista('Carles','Puyol',36,False),
    Futbolista('Sergio','Ramos',28,True),
    Futbolista('Andrés','Iniesta',30,True),
    Futbolista('Fernando','Torres',30,True),
    Futbolista('Leo','Baptistao',22,False),
    Futbolista('Juan','Baptistao',22,False),
    Futbolista('diego','Baptistao',22,False),
    Futbolista('camilo','Baptistao',22,False),
    Futbolista('Espin','Baptistao',22,False),
    Futbolista('Diego','Baptistao',22,False),
]

# %%
# PASO 1: Conexión al Server de MongoDB Pasandole el host y el puerto

client = MongoClient("mongodb+srv://danielgarcia_db_user:Windows25..@clusterdanielgarcia.6sl5wsx.mongodb.net/?retryWrites=true&w=majority&appName=ClusterDanielGarcia")

db = client.BDALMAC_UAO_2025_02

collection = db.Futbolistas

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
# PASO 4.1: "CREATE" -> Metemos los objetos futbolista (o documentos en Mongo) en la coleccion Futbolista
futbolistas_insertados = []
for futbolista in futbolistas:
    resultado = collection.insert_one(futbolista.toDBCollection())
    futbolistas_insertados.append(resultado.inserted_id)
#print("Futbolistas insertados: ", futbolistas_insertados)
print("Futbolistas insertados: ", futbolistas_insertados)
# Out:
# Futbolistas insertados:  [ObjectId('68e83d5122ae225288a3befb'), ObjectId('68e83d5122ae225288a3befc'), ObjectId('68e83d5122ae225288a3befd'), ObjectId('68e83d5122ae225288a3befe'), ObjectId('68e83d5122ae225288a3beff'), ObjectId('68e83d5122ae225288a3bf00'), ObjectId('68e83d5122ae225288a3bf01'), ObjectId('68e83d5222ae225288a3bf02'), ObjectId('68e83d5222ae225288a3bf03'), ObjectId('68e83d5222ae225288a3bf04'), ObjectId('68e83d5222ae225288a3bf05')]

# %%
# Actualizar 
resultado  = collection.update_one({"nombre":"Andrés"}, {"$set": {"nombre":"Andrés Juan"}})

print("Documento actualizado: ", resultado.modified_count)

# Futbolista('Sergio','Ramos',28,True),
#    Futbolista('Andrés','Iniesta',30,True),

#resultado  = collection.findByIdAndUpdate({'660ad4ebf338955d1a88f67f'}, {"$set": {"nombre":"Andrés Pedro"}})

#print("Documento actualizado: ", resultado.modified_count)



#Eliminar
# Out:
# Documento actualizado:  1

# %%
#SELECT * FROM Futbolistas
resultado2 = collection.find()

for fut in resultado2:
    print(fut)

#SELECT * FROM Futbolistas
#WHERE nombre = 'Andrés Juan'
resultado1 = collection.find({"nombre":'Andrés Juan'})

for fut in resultado1:
    print("RESULT", fut)



#{"nombre":'Andrés Juan'}
# Out:
# {'_id': ObjectId('68e82bb6b2f7aa2537bc3fc7'), 'nombre': 'Iker', 'apellidos': 'Casillas', 'edad': 65, 'internacional': 0}
# {'_id': ObjectId('68e82bb6b2f7aa2537bc3fc8'), 'nombre': 'Carles', 'apellidos': 'Puyol', 'edad': 65, 'internacional': 1}
# {'_id': ObjectId('68e82bb6b2f7aa2537bc3fc9'), 'nombre': 'Sergio', 'apellidos': 'Ramos', 'edad': 28, 'internacional': True}
# {'_id': ObjectId('68e82bb7b2f7aa2537bc3fcb'), 'nombre': 'Fernando', 'apellidos': 'Torres', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('68e82bb7b2f7aa2537bc3fcd'), 'nombre': 'James', 'apellidos': 'Rodriguez', 'edad': 34, 'internacional': True}
# {'_id': ObjectId('68e82bb7b2f7aa2537bc3fce'), 'nombre': 'Luis', 'apellidos': 'Diaz', 'edad': 28, 'internacional': False}
# {'_id': ObjectId('68e82bb7b2f7aa2537bc3fcf'), 'nombre': 'Dairo', 'apellidos': 'Moreno', 'edad': 40, 'internacional': False}
# {'_id': ObjectId('68e83cab22ae225288a3bef0'), 'nombre': 'Iker', 'apellidos': 'Casillas', 'edad': 65, 'internacional': True}
# {'_id': ObjectId('68e83cab22ae225288a3bef1'), 'nombre': 'Carles', 'apellidos': 'Puyol', 'edad': 65, 'internacional': False}
# {'_id': ObjectId('68e83cab22ae225288a3bef2'), 'nombre': 'Sergio', 'apellidos': 'Ramos', 'edad': 28, 'internacional': True}
# {'_id': ObjectId('68e83cab22ae225288a3bef3'), 'nombre': 'Andrés Juan', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('68e83cab22ae225288a3bef4'), 'nombre': 'Fernando', 'apellidos': 'Torres', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('68e83d5122ae225288a3befb'), 'nombre': 'Iker', 'apellidos': 'Casillas', 'edad': 65, 'internacional': True}
# {'_id': ObjectId('68e83d5122ae225288a3befc'), 'nombre': 'Carles', 'apellidos': 'Puyol', 'edad': 65, 'internacional': False}
# {'_id': ObjectId('68e83d5122ae225288a3befd'), 'nombre': 'Sergio', 'apellidos': 'Ramos', 'edad': 28, 'internacional': True}
# {'_id': ObjectId('68e83d5122ae225288a3befe'), 'nombre': 'Andrés', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('68e83d5122ae225288a3beff'), 'nombre': 'Fernando', 'apellidos': 'Torres', 'edad': 30, 'internacional': True}
# RESULT {'_id': ObjectId('68e83cab22ae225288a3bef3'), 'nombre': 'Andrés Juan', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}

# %%
resultado = collection.delete_one({"nombre":'Andrés Juan'})

if resultado.deleted_count == 1:
    print("Se elimino el documento")
else:
    print("No se elimino el documento")

resultado1 = collection.find({"nombre":'Andrés Juan'})

for fut in resultado1:
    print(fut)
# Out:
# Se elimino el documento
# {'_id': ObjectId('68e83cab22ae225288a3bef3'), 'nombre': 'Andrés Juan', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}

# %%
resultado  = collection.update_many({"nombre": {"$in": ["Iker", "Carles"]}}, {"$set": {"edad": 65}})

print (f"se actualziaron {resultado.modified_count} documentos")
# Out:
# se actualziaron 6 documentos

# %%
resultado = collection.delete_many({"apellidos": {"$regex":"^B"}})


if resultado.deleted_count > 0:
    print("Se eliminaron",resultado.deleted_count, "documentos")
else:
    print("No se eliminaron Documentos...")
# Out:
# Se eliminaron 13 documentos

# %%
print(futbolistas[0])
# Out:
# Nombre: Iker - Apellidos: Casillas - Edad: 33 - Internacional: True

# %%
import matplotlib.pyplot as plt

futbolistas2 = collection.find()

futbolistas_consultados = []
for fut in futbolistas2:
    #print(fut['nombre'])
    unFutbolista = Futbolista(fut['nombre'],fut['apellidos'],fut['edad'],fut['internacional'])
    futbolistas_consultados.append(unFutbolista)

#print(futbolistas_consultados)

# Lista de nombres y edades de los futbolistas
nombres = [futbolista.nombre for futbolista in futbolistas_consultados]
edades = [futbolista.edad for futbolista in futbolistas_consultados]

# Crear un gráfico de barras
plt.bar(nombres, edades)

# Agregar etiquetas a los ejes
plt.xlabel('Nombre')
plt.ylabel('Edad')

# Mostrar el gráfico
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Query the collection to get the ages of all the players
ages = collection.distinct('edad')

# Count the number of players for each age
counts = [collection.count_documents({'edad': age}) for age in ages]

# Create a bar chart using Matplotlib
plt.bar(ages, counts)
plt.title('Number of players by age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
import matplotlib.pyplot as plt

# Count the number of international and non-international players
num_international = collection.count_documents({'internacional': True})
num_non_international = collection.count_documents({'internacional': False})

print(num_international,num_non_international )

# Create a pie chart using Matplotlib
labels = ['International', 'Non-International']
sizes = [num_international, num_non_international]
explode = (0.1, 0)

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', startangle=90)
ax1.axis('equal')

plt.title('Percentage of international and non-international players')
plt.show()
# Out:
# 11 4

# %%
import matplotlib.pyplot as plt

# Get the ages of all players in the collection
ages = [futbolista["edad"] for futbolista in collection.find()]



# Create a histogram using Matplotlib
plt.hist(ages, bins=10, color='green')

plt.title('Distribution of player ages')
plt.xlabel('Age')
plt.ylabel('Frequency')

plt.show()

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.3.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\danie\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\danie\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\danie\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.3-cp313-cp313-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    -------------------- ------------------- 5.8/11.0 MB 38.0 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 29.6 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 26.0 MB/s eta 0:00:00
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.3.3 pytz-2025.2 tzdata-2025.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# Create a cursor to iterate over the collection
resultado = collection.find()

# Create a list to store the documents
documentos = []

# Iterate over the cursor and append the documents to the list
for document in resultado:
    documentos.append(document)

# Create a DataFrame from the list of documents
df = pd.DataFrame(documentos)

# Print the DataFrame
print(df)
# Out:
#                          _id       nombre  apellidos  edad internacional
# 0   68e82bb6b2f7aa2537bc3fc7         Iker   Casillas    65             0
# 1   68e82bb6b2f7aa2537bc3fc8       Carles      Puyol    65             1
# 2   68e82bb6b2f7aa2537bc3fc9       Sergio      Ramos    28          True
# 3   68e82bb7b2f7aa2537bc3fcb     Fernando     Torres    30          True
# 4   68e82bb7b2f7aa2537bc3fcd        James  Rodriguez    34          True
# 5   68e82bb7b2f7aa2537bc3fce         Luis       Diaz    28         False
# 6   68e82bb7b2f7aa2537bc3fcf        Dairo     Moreno    40         False
# 7   68e83cab22ae225288a3bef0         Iker   Casillas    65          True
# 8   68e83cab22ae225288a3bef1       Carles      Puyol    65         False
# 9   68e83cab22ae225288a3bef2       Sergio      Ramos    28          True
# 10  68e83cab22ae225288a3bef3  Andrés Juan    Iniesta    30          True
# 11  68e83cab22ae225288a3bef4     Fernando     Torres    30          True
# 12  68e83d5122ae225288a3befb         Iker   Casillas    65          True
# 13  68e83d5122ae225288a3befc       Carles      Puyol    65         False
# 14  68e83d5122ae225288a3befd       Sergio      Ramos    28          True
# 15  68e83d5122ae225288a3befe       Andrés    Iniesta    30          True
# 16  68e83d5122ae225288a3beff     Fernando     Torres    30          True

# %%
df.describe()
# Out:
#             edad
# count  17.000000
# mean   42.705882
# std    17.207428
# min    28.000000
# 25%    30.000000
# 50%    30.000000
# 75%    65.000000
# max    65.000000

# %%
df1 = df.drop_duplicates()
print(df1)
# Out:
#                          _id       nombre  apellidos  edad internacional
# 0   68e82bb6b2f7aa2537bc3fc7         Iker   Casillas    65             0
# 1   68e82bb6b2f7aa2537bc3fc8       Carles      Puyol    65             1
# 2   68e82bb6b2f7aa2537bc3fc9       Sergio      Ramos    28          True
# 3   68e82bb7b2f7aa2537bc3fcb     Fernando     Torres    30          True
# 4   68e82bb7b2f7aa2537bc3fcd        James  Rodriguez    34          True
# 5   68e82bb7b2f7aa2537bc3fce         Luis       Diaz    28         False
# 6   68e82bb7b2f7aa2537bc3fcf        Dairo     Moreno    40         False
# 7   68e83cab22ae225288a3bef0         Iker   Casillas    65          True
# 8   68e83cab22ae225288a3bef1       Carles      Puyol    65         False
# 9   68e83cab22ae225288a3bef2       Sergio      Ramos    28          True
# 10  68e83cab22ae225288a3bef3  Andrés Juan    Iniesta    30          True
# 11  68e83cab22ae225288a3bef4     Fernando     Torres    30          True
# 12  68e83d5122ae225288a3befb         Iker   Casillas    65          True
# 13  68e83d5122ae225288a3befc       Carles      Puyol    65         False
# 14  68e83d5122ae225288a3befd       Sergio      Ramos    28          True
# 15  68e83d5122ae225288a3befe       Andrés    Iniesta    30          True
# 16  68e83d5122ae225288a3beff     Fernando     Torres    30          True

# %%
df2 = df.drop_duplicates(subset=['nombre'])
print(df2)
# Out:
#                          _id       nombre apellidos  edad internacional
# 0   660ad4eaf338955d1a88f67c         Iker  Casillas    65             0
# 1   660ad4eaf338955d1a88f67d       Carles     Puyol    65             1
# 2   660ad4ebf338955d1a88f67e       Sergio     Ramos    28          True
# 3   660ad4ebf338955d1a88f680     Fernando    Torres    30          True
# 7   660ad7da7cad470e44bb017a  Andrés Juan   Iniesta    30          True
# 17  660d5c2d12987b15e0350c24       Andrés   Iniesta    30          True
